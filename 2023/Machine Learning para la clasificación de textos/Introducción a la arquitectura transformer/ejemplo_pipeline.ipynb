# %%
# !pip install transformers==4.28.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 59.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 97.8 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline


classifier = pipeline('sentiment-analysis',
                      model="pysentimiento/robertuito-sentiment-analysis")

sentences = ["¡Me encanta el macroentrenamiento, los cursos y tutoriales son lo máximo!",
                "Odio los lunes, no sirven para nada.",
                "El artículo es medio bueno; me gustó como presentaron los resultados."]

results = classifier(sentences)
for result in results:
    print(f"polaridad: {result['label']}, score: {round(result['score'], 4)}")
# Out:
# ...
# polaridad: POS, score: 0.9762
# polaridad: NEG, score: 0.9746
# polaridad: POS, score: 0.9682

# %% [markdown]
# # Nueva sección

# %% [markdown]
# # Nueva sección

# %%
sentences = ["¡Me encanta el macroentrenamiento, los cursos y tutoriales son lo máximo!",
                "Odio los lunes, no sirven para nada.",
                "El artículo es medio bueno; me gustó como presentaron los resultados."]

results = classifier(sentences)
print(results)
# Out:
# [{'label': 'POS', 'score': 0.9762054681777954}, {'label': 'NEG', 'score': 0.9746404886245728}, {'label': 'POS', 'score': 0.968230664730072}]
